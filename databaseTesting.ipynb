# %%
import sqlite3

# %%
# %load_ext sql
# %config SqlMagic.displaylimit = 100
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %sql sqlite:///nhlDatabase.db
# Out:
# Connecting to 'sqlite:///nhlDatabase.db'

# %%
import prettytable
prettytable.DEFAULT = 'DEFAULT'

# %%
# %sql SELECT * FROM simple_skater_stats WHERE situation = 'all' AND season = 2025 ORDER BY icetime_minutes DESC;
# Out:
# Running query in 'sqlite:///nhlDatabase.db'
# +--------+---------+-----------+-----------+-----------------------+------------+---------------+----------+--------------+-----------------+-------+--------+---------+--------+---------------+---------------+------+------------------------+---------------------+------------+-------------+--------------+-------------+---------------------+---------------------+-----------+-----+-----------------+-----------------------+
# | season |  phase  | situation | team_code |       team_name       | first_name |   last_name   | position | games_played | icetime_minutes | goals | xGoals | assists | points | shots_on_goal | shot_attempts | hits | faceoff_win_percentage | shooting_percentage | goalsPer60 | xGoalsPer60 | assistsPer60 | pointsPer60 | shots_on_goal_per60 | shot_attempts_per60 | hitsPer60 | +/- | penalty_minutes | penalty_minutes_drawn |
# ...

# %%
# Out:
# Running query in 'sqlite:///nhlDatabase.db'
# 2 rows affected.
# ++
# ||
# ++
# ++

# %%
# Out:
# Running query in 'sqlite:///nhlDatabase.db'
# 2 rows affected.
# ++
# ||
# ++
# ++

# %%
# Out:
#   Cell In[11], line 1
# ...
